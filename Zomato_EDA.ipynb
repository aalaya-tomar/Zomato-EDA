# %%
# !unzip '/content/archive (60).zip'
# Out:
# Archive:  /content/archive (60).zip
#   inflating: Country-Code.xlsx
#   inflating: zomato.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/zomato.csv',encoding='latin')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Has Online delivery'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Has Online delivery'>

# %%
df.isna().sum()/len(df)*100
# Out:
# Restaurant ID           0.000000
# Restaurant Name         0.000000
# Country Code            0.000000
# City                    0.000000
# Address                 0.000000
# Locality                0.000000
# Locality Verbose        0.000000
# Longitude               0.000000
# Latitude                0.000000
# Cuisines                0.094231
# Average Cost for two    0.000000
# Currency                0.000000
# Has Table booking       0.000000
# Has Online delivery     0.000000
# Is delivering now       0.000000
# Switch to order menu    0.000000
# Price range             0.000000
# Aggregate rating        0.000000
# Rating color            0.000000
# Rating text             0.000000
# Votes                   0.000000
# dtype: float64

# %%
df.dropna(axis=0,inplace=True)  #drop the missing rows permanently

# %%
df.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')
sns.displot(df['Aggregate rating'])
plt.show()

# %%
sns.boxplot(x='Aggregate rating',
            y='Votes',
            data=df)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Votes'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
sns.scatterplot(x='Average Cost for two',
                y='Votes',
                data=df)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Votes'>

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Average Cost for two'])
plt.xlabel('Average Cost for Two')
plt.show()

# %%
sns.pairplot(df[['Votes','Aggregate rating','Price range']])

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.146270  -0.224362 -0.052626
# Country Code               0.146270      1.000000  -0.694629  0.018049
# Longitude                 -0.224362     -0.694629   1.000000  0.045415
# Latitude                  -0.052626      0.018049   0.045415  1.000000
# Average Cost for two      -0.001629      0.043717   0.045948 -0.111080
# Price range               -0.134528      0.245363  -0.080257 -0.166735
# Aggregate rating          -0.327160      0.281295  -0.114733  0.000197
# Votes                     -0.147434      0.154361  -0.084371 -0.022914
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001629    -0.134528         -0.327160
# Country Code                      0.043717     0.245363          0.281295
# Longitude                         0.045948    -0.080257         -0.114733
# ...

# %%
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
df.shape
# Out:
# (9542, 21)

# %%
sns.scatterplot(x='Latitude',
                y='Longitude',
                data=df,
                hue='Has Table booking')
# Out:
# <Axes: xlabel='Latitude', ylabel='Longitude'>

# %%
df['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9542, dtype: object

# %%
text = "this,is,a,test,sentence"
text.split(',')
# Out:
# ['this', 'is', 'a', 'test', 'sentence']

# %%
df['count_cuisines'] = df['Cuisines'].apply(lambda x : len(x.split(',')))
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
df['City'].value_counts().head(10)
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Amritsar          21
# Bhubaneshwar      21
# Lucknow           21
# Name: City, dtype: int64

# %%
df['count_cuisines'].corr(df['Aggregate rating'])
# Out:
# 0.2503164288362204

# %%
sns.boxplot(x=df['Has Table booking'],y=df['Aggregate rating'])
# Out:
# <Axes: xlabel='Has Table booking', ylabel='Aggregate rating'>

# %%
df.groupby(['Has Table booking'])['Aggregate rating'].mean()
# Out:
# Has Table booking
# No     2.557956
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %%
df.groupby(['Has Online delivery'])['Aggregate rating'].mean()
# Out:
# Has Online delivery
# No     2.463517
# Yes    3.248837
# Name: Aggregate rating, dtype: float64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'count_cuisines'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
#
#   Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                No                   No           3              4.8
#
#    Rating color  Rating text Votes count_cuisines
# 0    Dark Green    Excellent   314              3
#
# [1 rows x 22 columns]

# %%
country = pd.read_excel('/content/Country-Code.xlsx')
country.head(3)
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil

# %%
data=df.merge(country,on='Country Code')
data.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Online delivery Is delivering now  \
# 0  French, Japanese, Desserts  ...                   No                No
#
#   Switch to order menu Price range Aggregate rating Rating color  Rating text  \
# 0                   No           3              4.8   Dark Green    Excellent
#
#    Votes count_cuisines      Country
# 0    314              3  Phillipines
#
# [1 rows x 23 columns]

# %%
data['Country'].value_counts().head(5).plot.bar()
# Out:
# <Axes: >

# %%
india = data[data['Country']=='India']
india.head(1)
# Out:
#      Restaurant ID Restaurant Name  Country Code  City  \
# 615        3400025      Jahanpanah             1  Agra
#
#                                                Address    Locality  \
# 615  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
#
#      Locality Verbose  Longitude   Latitude               Cuisines  ...  \
# 615  Agra Cantt, Agra  78.011544  27.161661  North Indian, Mughlai  ...
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 615                   No                No                   No           3
#
#     Aggregate rating Rating color  Rating text  Votes count_cuisines Country
# 615              3.9       Yellow         Good    140              2   India
#
# [1 rows x 23 columns]

# %%
india['City'].value_counts().head(5).plot.pie()
# Out:
# <Axes: ylabel='City'>

# %%
delhi = india[india['City']=='New Delhi']
delhi['Restaurant Name'].value_counts().head(10).plot.pie()
# Out:
# <Axes: ylabel='Restaurant Name'>

# %%
#Top rated restaurants in delhi
delhi.head(1)
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 2551       18287358      Food Cloud             1  New Delhi
#
#                     Address    Locality       Locality Verbose  Longitude  \
# 2551  Aaya Nagar, New Delhi  Aaya Nagar  Aaya Nagar, New Delhi        0.0
#
#       Latitude        Cuisines  ...  Has Online delivery Is delivering now  \
# 2551       0.0  Cuisine Varies  ...                   No                No
#
#      Switch to order menu Price range Aggregate rating Rating color  \
# 2551                   No           2              0.0        White
#
#       Rating text  Votes count_cuisines Country
# 2551    Not rated      2              1   India
#
# [1 rows x 23 columns]

# %%
delhi['Aggregate rating'].hist()
# Out:
# <Axes: >

# %%
delhi[delhi['Aggregate rating']>4.8]['Restaurant Name']
# Out:
# 3004           Naturals Ice Cream
# 3592    Indian Accent - The Manor
# 4289               Masala Library
# Name: Restaurant Name, dtype: object

# %%
#Create a restuarant simple recommendation system
delhi.head(1)
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 2551       18287358      Food Cloud             1  New Delhi
#
#                     Address    Locality       Locality Verbose  Longitude  \
# 2551  Aaya Nagar, New Delhi  Aaya Nagar  Aaya Nagar, New Delhi        0.0
#
#       Latitude        Cuisines  ...  Has Online delivery Is delivering now  \
# 2551       0.0  Cuisine Varies  ...                   No                No
#
#      Switch to order menu Price range Aggregate rating Rating color  \
# 2551                   No           2              0.0        White
#
#       Rating text  Votes count_cuisines Country
# 2551    Not rated      2              1   India
#
# [1 rows x 23 columns]

# %%
places = list(delhi['Locality'].value_counts().index)
places
# Out:
# ['Connaught Place',
#  'Rajouri Garden',
#  'Shahdara',
#  'Defence Colony',
#  'Pitampura',
#  'Malviya Nagar',
#  'Mayur Vihar Phase 1',
#  'Rajinder Nagar',
#  'Safdarjung',
#  'Satyaniketan',
#  'Karol Bagh',
#  'Krishna Nagar',
#  'Hauz Khas',
#  'Kalkaji',
#  'Mahipalpur',
#  'Mukherjee Nagar',
#  'Chandni Chowk',
#  'Shalimar Bagh',
#  'Greater Kailash (GK) 1',
#  'Greater Kailash (GK) 2',
#  'Kamla Nagar',
#  'Delhi University-GTB Nagar',
#  'Paharganj',
#  'Vasundhara Enclave',
#  'Jail Road',
#  'Najafgarh',
#  'Vikaspuri',
#  'Palam',
#  'Punjabi Bagh',
#  'Tilak Nagar',
#  'Uttam Nagar',
#  'Laxmi Nagar',
#  'Dilshad Garden',
#  'Jangpura',
#  'East of Kailash',
#  'Kirti Nagar',
#  'Paschim Vihar',
#  'Naraina',
#  'Subhash Nagar',
#  'East Patel Nagar',
#  'Preet Vihar',
#  'Rohini',
#  'Netaji Subhash Place',
#  'New Friends Colony',
#  'IP Extension',
#  'Green Park',
#  'Chittaranjan Park',
#  'Janakpuri',
#  'Khan Market',
#  'Daryaganj',
#  'Munirka',
# ...

# %%
delhi[delhi['Locality']==input('Enter the Locality')][['Restaurant Name','Address','Aggregate rating']]
# Out:
# Enter the LocalityJNU
#                 Restaurant Name  \
# 4346       34, Chowringhee Lane
# 4347                    Qureshi
# 4348     Shree Ram Sweet Centre
# 4349                     Teflas
# 4350        The Viraj Food Zone
# 4351                  RollsKing
# 4352      Secular House Canteen
# 4353     Amul Ice-Cream Parlour
# 4354  Sunny Restaurant & Tiffin
# 4355                Kerala Cafe
#
#                                                 Address  Aggregate rating
# 4346  61-D, Ground Floor, Ber Sarai Market, Opposite...               3.2
# 4347                   7, Kamal Complex, JNU, New Delhi               3.0
# 4348  DDA Market, Ber Sarai, Near IIT Delhi Hostel G...               2.7
# 4349            Opposite Narmada Hostel, JNU, New Delhi               3.4
# 4350                    61-B, Ber Sarai, JNU, New Delhi               3.2
# 4351  Shop 23, DDA Shopping Complex, Ber Serai, JNU,...               3.5
# ...
